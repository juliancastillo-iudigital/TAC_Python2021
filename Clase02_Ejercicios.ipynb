# %% [markdown]
# <p><img alt="IUDigital" height="140px" src="https://www.iudigital.edu.co/Style%20Library/images/logo-escudo.png" align="left" hspace="10px" vspace="0px"></p>
# <br><br><br><br><br><br>
# <p>
# <h1> <b> Introducción a Python con Google Colab </b> </h1>
# <hr size=10 noshade color="red">
# </p>
# <p>
# <img alt="CC" height="70px" src="https://creativecommons.org/images/deed/cc_blue_x2.png" align="left" hspace="0px" vspace="0px">
# <img alt="Attribution" height="70px" src="https://creativecommons.org/images/deed/attribution_icon_blue_x2.png" align="left" hspace="0px" vspace="0px">
# <img alt="NC" height="70px" src="https://creativecommons.org/images/deed/nc_blue_x2.png" align="left" hspace="0px" vspace="0px">
# <img alt="SA" height="70px" src="https://creativecommons.org/images/deed/sa_blue_x2.png" align="left" hspace="0px" vspace="0px">
# </p>
#
# <div align="right">
# <h1> <b> Por: Julián Andrés Castillo G. </b> </h1>
# <h2> Profesor Ocasional </h2>
# <a href="mailto:julian.castillo@iudigital.edu.co"> ✉ Julian Andres Castillo Grisales </a>
# </div>
#
# <br>
#
# **El presente curso hace parte de la Tecnología en Desarrollo de Software de la Institución Universitaria Digital de Antioquia.**
#
# Introducción a Google Colab

# %% [markdown]
# <p><a name="contents"></a></p>
#
# # **Ejercicios Sesión 2**
#
# - <a href="#s1">01. Introducción al lenguaje de programación Python</a><br>
# - <a href="#s2">02. Módulos, Librerías, ayudas y descripciones</a><br>
# - <a href="#s3">03. Variables</a><br>
# - <a href="#s4">04. Tipos de Datos</a><br>

# %% [markdown]
# <p><a name="s1"></a></p>
#
# # **01. Introducción al lenguaje de programación Python**
# <p>
# La identación o sangrado.
#
# Participación estudiantil con respecto a este contenido.
#
# **Algunas de las características notables de Python:**
#
# **Algunas características del lenguaje de programación de Python son:**
#
# **¿Cómo se realizan comentarios en Python?**
#
# </p>
#
# [[Contenidos]](#contents)

# %% [markdown]
# <p><a name="s2"></a></p>
#
# # **02. Módulos, Librerías, ayudas y descripciones**
# [[Contenidos]](#contents)
# <p>
#
# ## **Ejercicios con Módulos**
#
#
#
# 1.   Importar al menos 10 librerías
# 2.   Utilizar la función `dir()` para identificar sus funcionalidades
# 3.   Detallar el uso de `pip`
# 4.   Instalar una librería usando `pip`
# 5.   Usar la función `help` para detallar las características de una función
# 6.   Usar la función `help` para detallar las características de un método

# %% [markdown]
# <p><a name="s3"></a></p>
#
# # **03. Variables**
# [[Contenidos]](#contents)
#
#
# ## **Ejercicios con Módulos**
#
#
# >1.   Usar la función `print()` con una variable tipo texto
# >2.   Usar la función `print()` con una variable tipo entero
# >3.   Usar la función `print()` con una variable tipo flotante
# >4.   Usar la función `print()` con una variable tipo booleana
# >5.   Usar la función `print()` concatenar las variables previamente descritas
# >6.   Usar la función `type()` en las variables de los puntos 1, 2, 3 y 4
# >7.   Realiza conversiones explicitas sobre 5 variables de tipo flotante a tipo entero.
# >8.   Realiza conversiones implícitas sobre 5 variables de tipo entero a tipo flotante.
# >9.   Convierte a texto 3 de las ultimas variables.
# >10.  Crea 5 variables para cada una de las siguientes formas de nomenclatura de variables.
# >>*   Camel Case
# >>*   Pascal Case
# >>*   Snake Case
# >11.  Asigna el mismo valor a 3 variables en una sola línea de código
# >11.  Asigna el mismo valor a 3 variables en una sola línea de código

# %% [markdown]
# <p><a name="s4"></a></p>
#
# # **04. Tipos de Datos**
# [[Contenidos]](#contents)

# %% [markdown]
# <p>
#
#
# ## **Ejercicios con cadenas de texto**
#
# 1.   Crear una variable con el siguiente texto <br>
# `Las cadenas en Python están rodeadas por comillas simples o comillas dobles`
# 2.   Imprimir los valores `[31],[43],[15],[5],[26],[32],[6],[1],[3],[62],[62],[62],[62],[62],[62]` de la variable previa.
# 3.   Crear 5 variables tipo texto e identificar el largo de cada variable.
# 4.   Realizar 5 tipos de slicing ascendentes diferentes sobre las variables creadas.
# 5.   Realizar 5 tipos de slicing descendente diferentes sobre las variables creadas.
# 6.   Realizar 5 tipos conversiones diferentes sobre cada variable de tipo texto creada.
# 7.   Utilizando la función `format()`, realizar modificaciones a cada una de las 5 variables creadas para anexar datos numéricos con 5 variables numéricas adicionales.
#
#
# </p>
