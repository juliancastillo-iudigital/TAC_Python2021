# %% [markdown]
# <p><img alt="IUDigital" height="140px" src="https://www.iudigital.edu.co/Style%20Library/images/logo-escudo.png" align="left" hspace="10px" vspace="0px"></p>
# <br><br><br><br><br><br>
# <p>
# <h1> <b> Introducción a Python con Google Colab </b> </h1>
# <hr size=10 noshade color="red">
# </p>
# <p>
# <img alt="CC" height="70px" src="https://creativecommons.org/images/deed/cc_blue_x2.png" align="left" hspace="0px" vspace="0px">
# <img alt="Attribution" height="70px" src="https://creativecommons.org/images/deed/attribution_icon_blue_x2.png" align="left" hspace="0px" vspace="0px">
# <img alt="NC" height="70px" src="https://creativecommons.org/images/deed/nc_blue_x2.png" align="left" hspace="0px" vspace="0px">
# <img alt="SA" height="70px" src="https://creativecommons.org/images/deed/sa_blue_x2.png" align="left" hspace="0px" vspace="0px">
# </p>
#
# <div align="right">
# <h1> <b> Por: Julián Andrés Castillo G. </b> </h1>
# <h2> Profesor Ocasional </h2>
# <a href="mailto:julian.castillo@iudigital.edu.co"> ✉ Julian Andres Castillo Grisales </a>
# </div>
#
# <br>
#
# **El presente curso hace parte de la Tecnología en Desarrollo de Software de la Institución Universitaria Digital de Antioquia.**
#
# Introducción a Google Colab

# %% [markdown]
# <p><a name="contents"></a></p>
#
# # **Ejercicios de todos los contenidos**
#
# </p>

# %% [markdown]
# ## Ejercicio 1
# <p>
# Elabore algoritmo que lea dos datos enteros correspondientes a los catetos de un triángulo rectángulo y que calcule e imprima el valor de la hipotenusa de dicho triángulo.
#
# </p>

# %%
#Solución

# %% [markdown]
# ## Ejercicio 2
# <p>
#
# Que dada una edad, devolver si esa edad corresponde a un niño, a un adolescente, a un adulto o a un adulto mayor. En caso que el valor no pertenezca a ninguna de las categorías descritas, retorne la palabra “error”.
#
# </p>

# %%
#Solución

# %% [markdown]
# ## Ejercicio 3
# <p>
#
# Elabore algoritmo que lea dos números enteros y que produzca como salida la suma, resta, multiplicación, división y módulo del primero por el segundo.
#
# </p>

# %%
#Solución

# %% [markdown]
# ## Ejercicio 4
# <p>
#
# Elabore algoritmo que lea el nombre de un estudiante y las tres notas obtenidas en los exámenes de una materia. El algoritmo debe calcular la definitiva y producir un mensaje de felicitación si la materia fue aprobada, o un mensaje de reproche si la materia fue perdida. La materia se aprueba si obtiene como definitiva una nota mayor o igual que 3.0.
#
# </p>

# %%
#Solución

# %% [markdown]
# ## Ejercicio 5
# <p>
#
# Elabore algoritmo que lea un número entero menor que diez y determine si es primo o no.
#
# </p>

# %%
#Solución

# %% [markdown]
# ## Ejercicio 6
# <p>
#
# Elabore algoritmo que lea el nombre de un estudiante y su promedio acumulado de la carrera. El algoritmo debe imprimir el nombre del estudiante y alguno de los siguientes mensajes: ‘pésimo’, ‘malo’, ‘regular’, ‘bueno’ o ‘excelente’. El estudiante se considera pésimo si el promedio acumulado es menor o igual que uno; malo, si el promedio es mayor que uno y menor que tres; regular, si el promedio es mayor o igual que tres y menor que cuatro; bueno, si el promedio es mayor que cuatro y menor que cuatro con cinco, y excelente, si el promedio es mayor o igual que cuatro con cinco.
#
# </p>

# %%
#Solución

# %% [markdown]
# ## Ejercicio 7
# <p>
#
# Elabore un algoritmo que lea un número entero y que efectúe lo siguiente: si es múltiplo de cuatro, imprimir el número dividido por cuatro; si es múltiplo de 5, imprimir la quinta parte del número elevada al cuadrado; si es múltiplo de siete imprimir el número dividido por ocho, y si no es múltiplo de ninguno de los anteriores producir el mensaje ‘número extraño’.
#
# </p>

# %%
#Solución

# %% [markdown]
# ## Ejercicio 8
# <p>
#
# La empresa de productos de belleza 'El acné' otorga descuento a sus clientes según la siguiente clasificación: si es mayorista, tiene una antigüedad de más de dos años y el valor de la compra es mayor que 2.000.000 de pesos le da un descuento del 25%; si es mayorista, tiene una antigüedad menor o igual que dos años y el valor de la compra está entre 1.500.000 y 2.000.000 millones de pesos le da un descuento de 20%; si es minoritario, tiene una antigüedad superior a 5 años y el valor de la compra es superior 2.000.000 de pesos le da un descuento del 18%; si es ocasional y el valor de la compra es superior a 2.000.000 de pesos le da un descuento del 10%. En cualquier otro caso, la compañía no da ningún descuento. Elabore un algoritmo que lea: clase de cliente, antigüedad y valor de compra y determine el valor a pagar por la compra.
# Los códigos de clasificación del cliente son:
#
# >a)	Mayorista
# >
# >b)	Minorista
# >
# >c)	Ocasional
#
#
# </p>

# %%
#Solución

# %% [markdown]
# ## Ejercicio 9
# <p>
#
# Elabore un algoritmo que lea año y mes y que imprima el número de días que tiene el mes leído.
#
# </p>

# %%
#Solución

# %% [markdown]
# ## Ejercicio 10
# <p>
#
# Elabore un algoritmo que lea el nombre de una persona y su edad en años. El algoritmo debe imprimir el nombre de la persona y su clasificación de acuerdo a los siguientes criterios: la persona es: ‘niño’, si la edad está entre cero y diez años; ‘adolescente’, si la edad está entre once y dieciocho años; ‘adulto’, si la edad está entre diecinueve y treinta y cinco años; ‘maduro’, si la edad está entre treinta y seis y sesenta años, y ‘anciano’, si la edad es mayor de sesenta años.
#
# </p>

# %%
#Solución

# %% [markdown]
# ## Ejercicio 11
# <p>
#
# Suponga que usted está interesado en calcular el promedio de una materia de 7 notas con los siguientes porcentajes en cada nota:
#
# *   20%
# *   05%
# *   10%
# *   10%
# *   30%
# *   20%
# *   05%.
#
# </p>

# %%
#Solución

# %% [markdown]
# ## Ejercicio 12
# <p>
#
# Elabore un algoritmo que lea dos enteros positivos m y n, que calcule e imprima la sumatoria de todos los enteros desde m hasta n.
#
# </p>

# %%
#Solución

# %% [markdown]
# ## Ejercicio 13
# <p>
#
# Elabore Algoritmo que lea un entero n y que imprima todos los múltiplos de tres desde uno hasta n.
#
# </p>

# %%
#Solución

# %% [markdown]
# ## Ejercicio 14
# <p>
#
# Elabore un algoritmo que lea un entero n y que genere los n primeros términos de la serie de Fibonacci. La serie de Fibonacci se construye partiendo de que los dos primeros términos son el cero y el uno, y cada siguiente término se calcula como la suma de los dos anteriores. Ejemplo: 0, 1, 1, 2, 3, 5, 8, 13,…
#
# </p>

# %%
#Solución

# %% [markdown]
# ## Ejercicio 15
# <p>
#
# Elabore un algoritmo que lea un entero positivo n y que calcule e imprima el factorial de n.
#
# </p>

# %%
#Solución
